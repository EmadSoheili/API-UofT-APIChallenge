# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}&q='

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_desc,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | maceio
# Processing Record 2 of Set 1 | san javier
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | barquisimeto
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | bosaso
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 1 | kasamwa
# Processing Record 11 of Set 1 | ebreichsdorf
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | lompoc
# Processing Record 15 of Set 1 | vilaka
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 1 | manuk mangkaw
# Processing Record 19 of Set 1 | geraldton
# Processing Record 20 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 1 | shimoda
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | tanete
# Processing Record 25 of Set 1 | faanui
# Processing Record 26 of Set 1 | vestmannaeyjar
# Processing Record 27 of Set 1 | buraydah
# Processing Record 28 of Set 1 | asau
# Processing Record 29 of Set 1 | soller
# Processing Record 30 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | cedral
# Processing Record 35 of Set 1 | tuatapere
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | souillac
# Processing Record 38 of Set 1 | killybegs
# Processing Record 39 of Set 1 | nome
# Processing Record 40 of Set 1 | rosario
# Processing Record 41 of Set 1 | amarpur
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | rio grande
# Processing Record 46 of Set 1 | laguna
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | deputatskiy
# Processing Record 1 of Set 2 | airai
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | broome
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | adrar
# Processing Record 7 of Set 2 | hofn
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | mitsamiouli
# Processing Record 10 of Set 2 | san patricio
# Processing Record 11 of Set 2 | urumqi
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | ola
# Processing Record 14 of Set 2 | cine
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 17 of Set 2 | dudinka
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | norsup
# Processing Record 20 of Set 2 | torata
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | bandarbeyla
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | lujan
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | raudeberg
# Processing Record 29 of Set 2 | rikitea
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 2 | grand gaube
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | itarsi
# Processing Record 36 of Set 2 | pontes e lacerda
# Processing Record 37 of Set 2 | bathsheba
# Processing Record 38 of Set 2 | khandagayty
# Processing Record 39 of Set 2 | santa cruz
# Processing Record 40 of Set 2 | bolshiye uki
# City not found. Skipping...
# Processing Record 41 of Set 2 | tuktoyaktuk
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | lebu
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | norman wells
# Processing Record 47 of Set 2 | saint-philippe
# Processing Record 48 of Set 2 | port-gentil
# Processing Record 49 of Set 2 | nouadhibou
# Processing Record 50 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 3 | monroe
# Processing Record 2 of Set 3 | berlevag
# Processing Record 3 of Set 3 | bubaque
# Processing Record 4 of Set 3 | seoul
# Processing Record 5 of Set 3 | ivanteyevka
# Processing Record 6 of Set 3 | mecca
# Processing Record 7 of Set 3 | panino
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | vadso
# Processing Record 10 of Set 3 | kilembe
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | te anau
# Processing Record 13 of Set 3 | kijabe
# Processing Record 14 of Set 3 | chiman
# Processing Record 15 of Set 3 | flinders
# Processing Record 16 of Set 3 | aswan
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | mushie
# Processing Record 19 of Set 3 | marathon
# Processing Record 20 of Set 3 | minsk
# Processing Record 21 of Set 3 | bredasdorp
# Processing Record 22 of Set 3 | eschwege
# Processing Record 23 of Set 3 | carballo
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | alekseyevka
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | balabac
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | beringovskiy
# Processing Record 30 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 3 | tucurui
# Processing Record 32 of Set 3 | milkovo
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 3 | calbuco
# Processing Record 36 of Set 3 | praya
# Processing Record 37 of Set 3 | the valley
# Processing Record 38 of Set 3 | kaitangata
# Processing Record 39 of Set 3 | hay river
# Processing Record 40 of Set 3 | dixon
# Processing Record 41 of Set 3 | drayton valley
# Processing Record 42 of Set 3 | lishan
# Processing Record 43 of Set 3 | urucara
# Processing Record 44 of Set 3 | suclayin
# Processing Record 45 of Set 3 | abha
# Processing Record 46 of Set 3 | rio gallegos
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | hualmay
# Processing Record 49 of Set 3 | shihezi
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | jinchang
# Processing Record 2 of Set 4 | abu samrah
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | mar del plata
# Processing Record 5 of Set 4 | omsukchan
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | nhulunbuy
# Processing Record 8 of Set 4 | bundi
# Processing Record 9 of Set 4 | quatre cocos
# Processing Record 10 of Set 4 | havlickuv brod
# Processing Record 11 of Set 4 | tangier
# Processing Record 12 of Set 4 | isangel
# Processing Record 13 of Set 4 | sinnamary
# Processing Record 14 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 4 | georgetown
# Processing Record 17 of Set 4 | megion
# Processing Record 18 of Set 4 | teahupoo
# Processing Record 19 of Set 4 | mahebourg
# Processing Record 20 of Set 4 | beloha
# Processing Record 21 of Set 4 | keetmanshoop
# Processing Record 22 of Set 4 | nizwa
# Processing Record 23 of Set 4 | daphne
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | shima
# Processing Record 26 of Set 4 | vaini
# Processing Record 27 of Set 4 | vanimo
# Processing Record 28 of Set 4 | talnakh
# Processing Record 29 of Set 4 | zhigansk
# Processing Record 30 of Set 4 | kruisfontein
# Processing Record 31 of Set 4 | aklavik
# Processing Record 32 of Set 4 | santiago de cuba
# Processing Record 33 of Set 4 | iquique
# Processing Record 34 of Set 4 | chapais
# Processing Record 35 of Set 4 | anadyr
# Processing Record 36 of Set 4 | cap malheureux
# Processing Record 37 of Set 4 | corrente
# Processing Record 38 of Set 4 | ngunguru
# Processing Record 39 of Set 4 | moyale
# Processing Record 40 of Set 4 | valls
# Processing Record 41 of Set 4 | noyabrsk
# Processing Record 42 of Set 4 | cortes
# Processing Record 43 of Set 4 | hami
# Processing Record 44 of Set 4 | tessalit
# Processing Record 45 of Set 4 | ostrovnoy
# Processing Record 46 of Set 4 | port hardy
# Processing Record 47 of Set 4 | fomboni
# Processing Record 48 of Set 4 | makinsk
# Processing Record 49 of Set 4 | puerto escondido
# Processing Record 50 of Set 4 | cockburn town
# Processing Record 1 of Set 5 | malpura
# Processing Record 2 of Set 5 | youghal
# Processing Record 3 of Set 5 | monrovia
# Processing Record 4 of Set 5 | esperance
# Processing Record 5 of Set 5 | labuhan
# Processing Record 6 of Set 5 | tasiilaq
# Processing Record 7 of Set 5 | saint george
# Processing Record 8 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 9 of Set 5 | saskylakh
# Processing Record 10 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | tautira
# Processing Record 14 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 5 | saldanha
# Processing Record 16 of Set 5 | stornoway
# Processing Record 17 of Set 5 | katsuura
# Processing Record 18 of Set 5 | qasigiannguit
# Processing Record 19 of Set 5 | krasnogorskiy
# Processing Record 20 of Set 5 | zykovo
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 5 | garden city
# Processing Record 23 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | ancud
# Processing Record 26 of Set 5 | aykhal
# Processing Record 27 of Set 5 | benghazi
# Processing Record 28 of Set 5 | kemijarvi
# Processing Record 29 of Set 5 | washington
# Processing Record 30 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 31 of Set 5 | kpagouda
# City not found. Skipping...
# Processing Record 32 of Set 5 | merauke
# Processing Record 33 of Set 5 | ratnagiri
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | plouzane
# Processing Record 36 of Set 5 | yar-sale
# Processing Record 37 of Set 5 | berwick
# Processing Record 38 of Set 5 | hambantota
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | west melbourne
# Processing Record 41 of Set 5 | fortuna
# Processing Record 42 of Set 5 | myitkyina
# Processing Record 43 of Set 5 | qaqortoq
# Processing Record 44 of Set 5 | veraval
# Processing Record 45 of Set 5 | pascagoula
# Processing Record 46 of Set 5 | tura
# Processing Record 47 of Set 5 | solwezi
# Processing Record 48 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 5 | el tocuyo
# Processing Record 50 of Set 5 | severo-kurilsk
# Processing Record 1 of Set 6 | belyy yar
# Processing Record 2 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 6 | amalapuram
# Processing Record 4 of Set 6 | phuket
# Processing Record 5 of Set 6 | sao felix do xingu
# Processing Record 6 of Set 6 | pevek
# Processing Record 7 of Set 6 | marsa matruh
# Processing Record 8 of Set 6 | hope
# Processing Record 9 of Set 6 | zhezkazgan
# Processing Record 10 of Set 6 | fare
# Processing Record 11 of Set 6 | edinburgh
# Processing Record 12 of Set 6 | iki-burul
# Processing Record 13 of Set 6 | comodoro rivadavia
# Processing Record 14 of Set 6 | lac du bonnet
# Processing Record 15 of Set 6 | victoria
# Processing Record 16 of Set 6 | semnan
# Processing Record 17 of Set 6 | morant bay
# Processing Record 18 of Set 6 | nemuro
# Processing Record 19 of Set 6 | bethel
# Processing Record 20 of Set 6 | priargunsk
# Processing Record 21 of Set 6 | sangar
# Processing Record 22 of Set 6 | halifax
# Processing Record 23 of Set 6 | guerrero negro
# Processing Record 24 of Set 6 | naco
# Processing Record 25 of Set 6 | yakovlevka
# Processing Record 26 of Set 6 | cukai
# Processing Record 27 of Set 6 | abu kamal
# Processing Record 28 of Set 6 | salalah
# Processing Record 29 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 30 of Set 6 | nueva germania
# Processing Record 31 of Set 6 | tierra blanca
# Processing Record 32 of Set 6 | coquimbo
# Processing Record 33 of Set 6 | linxia
# Processing Record 34 of Set 6 | meulaboh
# Processing Record 35 of Set 6 | barinas
# Processing Record 36 of Set 6 | east london
# Processing Record 37 of Set 6 | port alfred
# Processing Record 38 of Set 6 | sisimiut
# Processing Record 39 of Set 6 | phalaborwa
# Processing Record 40 of Set 6 | vila franca do campo
# Processing Record 41 of Set 6 | smidovich
# Processing Record 42 of Set 6 | avera
# Processing Record 43 of Set 6 | college
# Processing Record 44 of Set 6 | dunedin
# Processing Record 45 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 46 of Set 6 | troitsko-pechorsk
# Processing Record 47 of Set 6 | iqaluit
# Processing Record 48 of Set 6 | ornskoldsvik
# Processing Record 49 of Set 6 | provideniya
# Processing Record 50 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 7 | oranmore
# Processing Record 2 of Set 7 | tiznit
# Processing Record 3 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 7 | sept-iles
# Processing Record 5 of Set 7 | ziro
# Processing Record 6 of Set 7 | pandamatenga
# Processing Record 7 of Set 7 | port lincoln
# Processing Record 8 of Set 7 | maningrida
# Processing Record 9 of Set 7 | walvis bay
# Processing Record 10 of Set 7 | havre-saint-pierre
# Processing Record 11 of Set 7 | cairns
# Processing Record 12 of Set 7 | cuicatlan
# Processing Record 13 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 7 | kailua
# Processing Record 15 of Set 7 | vao
# Processing Record 16 of Set 7 | severnoye
# Processing Record 17 of Set 7 | goma
# Processing Record 18 of Set 7 | nyahururu
# Processing Record 19 of Set 7 | buala
# Processing Record 20 of Set 7 | bhuj
# Processing Record 21 of Set 7 | constitucion
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | ocos
# Processing Record 24 of Set 7 | zwedru
# Processing Record 25 of Set 7 | mackenzie
# Processing Record 26 of Set 7 | berezovyy
# Processing Record 27 of Set 7 | cayenne
# Processing Record 28 of Set 7 | paciran
# Processing Record 29 of Set 7 | thompson
# Processing Record 30 of Set 7 | pemba
# Processing Record 31 of Set 7 | barroualie
# City not found. Skipping...
# Processing Record 32 of Set 7 | makungu
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | kisanga
# Processing Record 35 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 36 of Set 7 | port hedland
# Processing Record 37 of Set 7 | high rock
# Processing Record 38 of Set 7 | trairi
# Processing Record 39 of Set 7 | gua musang
# Processing Record 40 of Set 7 | husavik
# Processing Record 41 of Set 7 | surt
# Processing Record 42 of Set 7 | taoudenni
# Processing Record 43 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 7 | atyrau
# Processing Record 45 of Set 7 | vodnyy
# Processing Record 46 of Set 7 | fairbanks
# Processing Record 47 of Set 7 | los llanos de aridane
# Processing Record 48 of Set 7 | kropotkin
# Processing Record 49 of Set 7 | mount isa
# Processing Record 50 of Set 7 | maragogi
# Processing Record 1 of Set 8 | sitka
# Processing Record 2 of Set 8 | berlin
# Processing Record 3 of Set 8 | ayan
# Processing Record 4 of Set 8 | charters towers
# Processing Record 5 of Set 8 | ji-parana
# City not found. Skipping...
# Processing Record 6 of Set 8 | arman
# Processing Record 7 of Set 8 | shingu
# Processing Record 8 of Set 8 | benjamin constant
# Processing Record 9 of Set 8 | bar harbor
# Processing Record 10 of Set 8 | ontario
# Processing Record 11 of Set 8 | kyzyl
# Processing Record 12 of Set 8 | gorontalo
# Processing Record 13 of Set 8 | dubai
# Processing Record 14 of Set 8 | villanueva de la serena
# Processing Record 15 of Set 8 | honiara
# Processing Record 16 of Set 8 | rognan
# Processing Record 17 of Set 8 | pauini
# Processing Record 18 of Set 8 | bom conselho
# Processing Record 19 of Set 8 | batagay-alyta
# Processing Record 20 of Set 8 | soure
# Processing Record 21 of Set 8 | port hawkesbury
# Processing Record 22 of Set 8 | jacareacanga
# Processing Record 23 of Set 8 | puerto narino
# Processing Record 24 of Set 8 | dawei
# Processing Record 25 of Set 8 | nadym
# Processing Record 26 of Set 8 | bolonchen
# City not found. Skipping...
# Processing Record 27 of Set 8 | gamba
# Processing Record 28 of Set 8 | ciudad bolivar
# Processing Record 29 of Set 8 | trinidad
# Processing Record 30 of Set 8 | hamilton
# Processing Record 31 of Set 8 | heihe
# Processing Record 32 of Set 8 | manaure
# Processing Record 33 of Set 8 | koutiala
# Processing Record 34 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 8 | payakumbuh
# Processing Record 36 of Set 8 | berbera
# Processing Record 37 of Set 8 | kavieng
# Processing Record 38 of Set 8 | launceston
# Processing Record 39 of Set 8 | malaut
# Processing Record 40 of Set 8 | bengkulu
# Processing Record 41 of Set 8 | novaya zaimka
# Processing Record 42 of Set 8 | fonte boa
# Processing Record 43 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 44 of Set 8 | moose factory
# Processing Record 45 of Set 8 | moindou
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | bonavista
# Processing Record 48 of Set 8 | bolobo
# Processing Record 49 of Set 8 | coihaique
# Processing Record 50 of Set 8 | bukachacha
# Processing Record 1 of Set 9 | padang
# Processing Record 2 of Set 9 | sukhumi
# Processing Record 3 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 9 | orlik
# Processing Record 5 of Set 9 | mount gambier
# Processing Record 6 of Set 9 | santa isabel do rio negro
# Processing Record 7 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 9 | gizo
# Processing Record 9 of Set 9 | wad madani
# Processing Record 10 of Set 9 | cabedelo
# Processing Record 11 of Set 9 | bitung
# Processing Record 12 of Set 9 | koungheul
# Processing Record 13 of Set 9 | high level
# Processing Record 14 of Set 9 | oktyabrskiy
# Processing Record 15 of Set 9 | sambava
# Processing Record 16 of Set 9 | luderitz
# Processing Record 17 of Set 9 | piombino
# Processing Record 18 of Set 9 | eureka
# Processing Record 19 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 9 | tokmak
# Processing Record 21 of Set 9 | aksu
# Processing Record 22 of Set 9 | belaya gora
# Processing Record 23 of Set 9 | durgapur
# Processing Record 24 of Set 9 | sola
# Processing Record 25 of Set 9 | komsomolskiy
# Processing Record 26 of Set 9 | wajir
# Processing Record 27 of Set 9 | pimentel
# Processing Record 28 of Set 9 | narsaq
# Processing Record 29 of Set 9 | nata
# Processing Record 30 of Set 9 | muisne
# Processing Record 31 of Set 9 | batemans bay
# Processing Record 32 of Set 9 | rafraf
# Processing Record 33 of Set 9 | general pico
# Processing Record 34 of Set 9 | yenagoa
# Processing Record 35 of Set 9 | chagoda
# Processing Record 36 of Set 9 | garissa
# Processing Record 37 of Set 9 | jaicos
# Processing Record 38 of Set 9 | olinda
# Processing Record 39 of Set 9 | ahipara
# Processing Record 40 of Set 9 | ribeira grande
# Processing Record 41 of Set 9 | bouar
# Processing Record 42 of Set 9 | kloulklubed
# Processing Record 43 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 9 | takoradi
# Processing Record 45 of Set 9 | payo
# Processing Record 46 of Set 9 | maloy
# Processing Record 47 of Set 9 | pipri
# Processing Record 48 of Set 9 | coahuayana
# Processing Record 49 of Set 9 | storslett
# Processing Record 50 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 1 of Set 10 | pucara
# Processing Record 2 of Set 10 | panama city
# Processing Record 3 of Set 10 | garowe
# Processing Record 4 of Set 10 | atikokan
# Processing Record 5 of Set 10 | jishou
# Processing Record 6 of Set 10 | leningradskiy
# Processing Record 7 of Set 10 | mansa
# Processing Record 8 of Set 10 | eresos
# Processing Record 9 of Set 10 | creel
# Processing Record 10 of Set 10 | vila
# Processing Record 11 of Set 10 | karacakoy
# Processing Record 12 of Set 10 | manali
# Processing Record 13 of Set 10 | port blair
# Processing Record 14 of Set 10 | sai buri
# Processing Record 15 of Set 10 | warkworth
# Processing Record 16 of Set 10 | jaipur hat
# City not found. Skipping...
# Processing Record 17 of Set 10 | floro
# Processing Record 18 of Set 10 | mayor pablo lagerenza
# Processing Record 19 of Set 10 | vila velha
# Processing Record 20 of Set 10 | valera
# Processing Record 21 of Set 10 | ballarpur
# Processing Record 22 of Set 10 | rudbar
# Processing Record 23 of Set 10 | donskoye
# Processing Record 24 of Set 10 | lisakovsk
# Processing Record 25 of Set 10 | lagoa
# Processing Record 26 of Set 10 | beaupre
# Processing Record 27 of Set 10 | virginia beach
# Processing Record 28 of Set 10 | havre
# Processing Record 29 of Set 10 | khandyga
# Processing Record 30 of Set 10 | dwarka
# Processing Record 31 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 32 of Set 10 | saijo
# Processing Record 33 of Set 10 | waingapu
# Processing Record 34 of Set 10 | kushiro
# Processing Record 35 of Set 10 | sorong
# Processing Record 36 of Set 10 | plettenberg bay
# Processing Record 37 of Set 10 | gerash
# Processing Record 38 of Set 10 | koumac
# Processing Record 39 of Set 10 | cacador
# Processing Record 40 of Set 10 | rocha
# Processing Record 41 of Set 10 | lethem
# Processing Record 42 of Set 10 | peceneaga
# Processing Record 43 of Set 10 | jamame
# Processing Record 44 of Set 10 | tymovskoye
# Processing Record 45 of Set 10 | margate
# Processing Record 46 of Set 10 | acapulco
# Processing Record 47 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 10 | senneterre
# Processing Record 49 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 10 | cheremshan
# Processing Record 1 of Set 11 | brae
# Processing Record 2 of Set 11 | ishinomaki
# Processing Record 3 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 4 of Set 11 | nabire
# Processing Record 5 of Set 11 | lubango
# Processing Record 6 of Set 11 | gikongoro
# Processing Record 7 of Set 11 | alice springs
# Processing Record 8 of Set 11 | marsaxlokk
# Processing Record 9 of Set 11 | carson city
# Processing Record 10 of Set 11 | chara
# Processing Record 11 of Set 11 | bilibino
# Processing Record 12 of Set 11 | fukue
# Processing Record 13 of Set 11 | plaster rock
# Processing Record 14 of Set 11 | alghero
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | la serena
# Processing Record 17 of Set 11 | rawson
# Processing Record 18 of Set 11 | matara
# Processing Record 19 of Set 11 | mahibadhoo
# Processing Record 20 of Set 11 | mehamn
# Processing Record 21 of Set 11 | mackay
# Processing Record 22 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 11 | spornoye
# Processing Record 25 of Set 11 | agadez
# Processing Record 26 of Set 11 | sirjan
# Processing Record 27 of Set 11 | muravlenko
# Processing Record 28 of Set 11 | nevesinje
# Processing Record 29 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 11 | touros
# Processing Record 31 of Set 11 | buon me thuot
# City not found. Skipping...
# Processing Record 32 of Set 11 | kontagora
# Processing Record 33 of Set 11 | chicama
# Processing Record 34 of Set 11 | lazaro cardenas
# Processing Record 35 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 11 | sitio novo do tocantins
# Processing Record 37 of Set 11 | playas
# Processing Record 38 of Set 11 | qui nhon
# Processing Record 39 of Set 11 | kolpny
# Processing Record 40 of Set 11 | nenjiang
# Processing Record 41 of Set 11 | praia da vitoria
# Processing Record 42 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 11 | nacala
# Processing Record 44 of Set 11 | canton
# Processing Record 45 of Set 11 | naze
# Processing Record 46 of Set 11 | shepsi
# Processing Record 47 of Set 11 | yatou
# Processing Record 48 of Set 11 | marawi
# Processing Record 49 of Set 11 | tarko-sale
# Processing Record 50 of Set 11 | ust-kut
# Processing Record 1 of Set 12 | pisco
# Processing Record 2 of Set 12 | faya
# Processing Record 3 of Set 12 | sao mateus do maranhao
# Processing Record 4 of Set 12 | taksimo
# Processing Record 5 of Set 12 | buzmeyin
# Processing Record 6 of Set 12 | santa fe
# Processing Record 7 of Set 12 | manokwari
# Processing Record 8 of Set 12 | henties bay
# Processing Record 9 of Set 12 | ondjiva
# Processing Record 10 of Set 12 | vestmanna
# Processing Record 11 of Set 12 | iquitos
# Processing Record 12 of Set 12 | evanston
# Processing Record 13 of Set 12 | road town
# Processing Record 14 of Set 12 | khani
# Processing Record 15 of Set 12 | lata
# Processing Record 16 of Set 12 | sobolevo
# Processing Record 17 of Set 12 | san cristobal
# Processing Record 18 of Set 12 | lonavale
# Processing Record 19 of Set 12 | harseni
# Processing Record 20 of Set 12 | acarau
# Processing Record 21 of Set 12 | nguruka
# Processing Record 22 of Set 12 | huarmey
# Processing Record 23 of Set 12 | tabuk
# Processing Record 24 of Set 12 | abalak
# Processing Record 25 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 26 of Set 12 | usinsk
# Processing Record 27 of Set 12 | juneau
# Processing Record 28 of Set 12 | kiama
# Processing Record 29 of Set 12 | estrela
# Processing Record 30 of Set 12 | royan
# Processing Record 31 of Set 12 | axim
# Processing Record 32 of Set 12 | lakhnadon
# Processing Record 33 of Set 12 | toora-khem
# Processing Record 34 of Set 12 | palmer
# Processing Record 35 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 36 of Set 12 | buckeye
# Processing Record 37 of Set 12 | puerto colombia
# Processing Record 38 of Set 12 | bullhead city
# Processing Record 39 of Set 12 | cabangahan
# Processing Record 40 of Set 12 | vikulovo
# Processing Record 41 of Set 12 | kutum
# Processing Record 42 of Set 12 | iskilip
# Processing Record 43 of Set 12 | matucana
# Processing Record 44 of Set 12 | anloga
# Processing Record 45 of Set 12 | champua
# Processing Record 46 of Set 12 | kahului
# Processing Record 47 of Set 12 | ekhabi
# Processing Record 48 of Set 12 | muscat
# Processing Record 49 of Set 12 | nicoya
# Processing Record 50 of Set 12 | krasnystaw
# Processing Record 1 of Set 13 | kidal
# Processing Record 2 of Set 13 | hakkari
# Processing Record 3 of Set 13 | esso
# Processing Record 4 of Set 13 | manicore
# Processing Record 5 of Set 13 | mme
# City not found. Skipping...
# Processing Record 6 of Set 13 | nosy varika
# Processing Record 7 of Set 13 | prince rupert
# Processing Record 8 of Set 13 | dumas
# Processing Record 9 of Set 13 | saint-pierre
# Processing Record 10 of Set 13 | olga
# Processing Record 11 of Set 13 | lukuledi
# Processing Record 12 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 13 | havoysund
# Processing Record 14 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 15 of Set 13 | gazanjyk
# Processing Record 16 of Set 13 | mazatlan
# Processing Record 17 of Set 13 | parainen
# Processing Record 18 of Set 13 | almeirim
# Processing Record 19 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 20 of Set 13 | kyshtovka
# Processing Record 21 of Set 13 | roblin
# Processing Record 22 of Set 13 | ixtapa
# Processing Record 23 of Set 13 | goderich
# Processing Record 24 of Set 13 | sarab
# Processing Record 25 of Set 13 | lavrentiya
# Processing Record 26 of Set 13 | sompeta
# Processing Record 27 of Set 13 | atar
# Processing Record 28 of Set 13 | ijaki
# City not found. Skipping...
# Processing Record 29 of Set 13 | vysha
# Processing Record 30 of Set 13 | alofi
# Processing Record 31 of Set 13 | san ramon
# Processing Record 32 of Set 13 | mianyang
# Processing Record 33 of Set 13 | karratha
# Processing Record 34 of Set 13 | ingham
# Processing Record 35 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 13 | rampura
# Processing Record 37 of Set 13 | innisfail
# Processing Record 38 of Set 13 | newport
# Processing Record 39 of Set 13 | san quintin
# Processing Record 40 of Set 13 | seinajoki
# Processing Record 41 of Set 13 | labrea
# Processing Record 42 of Set 13 | alexandria
# Processing Record 43 of Set 13 | toyooka
# Processing Record 44 of Set 13 | romny
# Processing Record 45 of Set 13 | olafsvik
# Processing Record 46 of Set 13 | mezhevoy
# Processing Record 47 of Set 13 | cabra
# Processing Record 48 of Set 13 | seki
# Processing Record 49 of Set 13 | auray
# Processing Record 50 of Set 13 | jablanica
# Processing Record 1 of Set 14 | louga
# Processing Record 2 of Set 14 | tubmanburg
# Processing Record 3 of Set 14 | jaisalmer
# Processing Record 4 of Set 14 | nichinan
# Processing Record 5 of Set 14 | xingyi
# Processing Record 6 of Set 14 | valparaiso
# Processing Record 7 of Set 14 | shelburne
# Processing Record 8 of Set 14 | dabat
# Processing Record 9 of Set 14 | zelenoborskiy
# Processing Record 10 of Set 14 | anito
# Processing Record 11 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 12 of Set 14 | colares
# Processing Record 13 of Set 14 | opotiki
# Processing Record 14 of Set 14 | victor harbor
# Processing Record 15 of Set 14 | tilichiki
# Processing Record 16 of Set 14 | mabaruma
# Processing Record 17 of Set 14 | shebalino
# Processing Record 18 of Set 14 | glace bay
# Processing Record 19 of Set 14 | karamken
# City not found. Skipping...
# Processing Record 20 of Set 14 | renqiu
# Processing Record 21 of Set 14 | kamenka
# Processing Record 22 of Set 14 | asilah
# Processing Record 23 of Set 14 | surgut
# Processing Record 24 of Set 14 | kyren
# Processing Record 25 of Set 14 | verkhoyansk
# Processing Record 26 of Set 14 | villazon
# Processing Record 27 of Set 14 | cururupu
# Processing Record 28 of Set 14 | porto novo
# Processing Record 29 of Set 14 | porbandar
# Processing Record 30 of Set 14 | padong
# Processing Record 31 of Set 14 | adre
# Processing Record 32 of Set 14 | riyadh
# Processing Record 33 of Set 14 | west odessa
# Processing Record 34 of Set 14 | thinadhoo
# Processing Record 35 of Set 14 | antalaha
# Processing Record 36 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 14 | nuuk
# Processing Record 38 of Set 14 | evensk
# Processing Record 39 of Set 14 | lakes entrance
# Processing Record 40 of Set 14 | along
# Processing Record 41 of Set 14 | slave lake
# Processing Record 42 of Set 14 | rosetta
# Processing Record 43 of Set 14 | makat
# Processing Record 44 of Set 14 | wewak
# Processing Record 45 of Set 14 | tsaratanana
# Processing Record 46 of Set 14 | okhotsk
# Processing Record 47 of Set 14 | taber
# Processing Record 48 of Set 14 | ust-uda
# Processing Record 49 of Set 14 | pointe michel
# Processing Record 50 of Set 14 | sakaiminato
# Processing Record 1 of Set 15 | teguldet
# Processing Record 2 of Set 15 | nanakuli
# Processing Record 3 of Set 15 | little current
# Processing Record 4 of Set 15 | birin
# Processing Record 5 of Set 15 | maxixe
# Processing Record 6 of Set 15 | palaiokhora
# City not found. Skipping...
# Processing Record 7 of Set 15 | poquoson
# Processing Record 8 of Set 15 | acajutla
# Processing Record 9 of Set 15 | paucartambo
# City not found. Skipping...
# Processing Record 10 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 11 of Set 15 | chegdomyn
# Processing Record 12 of Set 15 | okha
# Processing Record 13 of Set 15 | birjand
# Processing Record 14 of Set 15 | shimsk
# Processing Record 15 of Set 15 | huntsville
# Processing Record 16 of Set 15 | karatau
# Processing Record 17 of Set 15 | acaponeta
# Processing Record 18 of Set 15 | banjar
# Processing Record 19 of Set 15 | pak phanang
# Processing Record 20 of Set 15 | strai
# Processing Record 21 of Set 15 | nuevo casas grandes
# Processing Record 22 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 23 of Set 15 | torbat-e jam
# Processing Record 24 of Set 15 | miles city
# Processing Record 25 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 26 of Set 15 | grindavik
# Processing Record 27 of Set 15 | potenza
# Processing Record 28 of Set 15 | kuytun
# Processing Record 29 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 15 | ust-kulom
# Processing Record 31 of Set 15 | buin
# Processing Record 32 of Set 15 | macas
# Processing Record 33 of Set 15 | general jose eduvigis diaz
# Processing Record 34 of Set 15 | kudahuvadhoo
# Processing Record 35 of Set 15 | samana
# Processing Record 36 of Set 15 | nador
# Processing Record 37 of Set 15 | saint-augustin
# Processing Record 38 of Set 15 | lianzhou
# Processing Record 39 of Set 15 | pizarro
# Processing Record 40 of Set 15 | carutapera
# Processing Record 41 of Set 15 | roma
# Processing Record 42 of Set 15 | teknaf
# Processing Record 43 of Set 15 | caravelas
# Processing Record 44 of Set 15 | tsimlyansk
# Processing Record 45 of Set 15 | moron
# Processing Record 46 of Set 15 | sayyan
# Processing Record 47 of Set 15 | kerema
# Processing Record 48 of Set 15 | fiche
# Processing Record 49 of Set 15 | jumla
# Processing Record 50 of Set 15 | lubao
# Processing Record 1 of Set 16 | taree
# Processing Record 2 of Set 16 | mirante do paranapanema
# Processing Record 3 of Set 16 | west bay
# Processing Record 4 of Set 16 | makamba
# Processing Record 5 of Set 16 | boa vista
# Processing Record 6 of Set 16 | kalmunai
# Processing Record 7 of Set 16 | vastervik
# City not found. Skipping...
# Processing Record 8 of Set 16 | lopatyn
# Processing Record 9 of Set 16 | pangnirtung
# Processing Record 10 of Set 16 | marsh harbour
# Processing Record 11 of Set 16 | zawiercie
# Processing Record 12 of Set 16 | haines junction
# Processing Record 13 of Set 16 | barra
# Processing Record 14 of Set 16 | zeya
# Processing Record 15 of Set 16 | richards bay
# Processing Record 16 of Set 16 | clarence town
# Processing Record 17 of Set 16 | atambua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                 City Country                 Date       Description      Lat  \
# 0             Maceio      BR  2022-10-02 08:16:18        few clouds  -9.6658
# 1         San Javier      ES  2022-10-02 08:17:39         clear sky  37.8063
# 2         Sao Filipe      CV  2022-10-02 08:17:40   overcast clouds  14.8961
# 3       Barquisimeto      VE  2022-10-02 08:17:40  scattered clouds  10.0739
# 4          Cape Town      ZA  2022-10-02 08:17:08         clear sky -33.9258
# 5  Sao Joao Da Barra      BR  2022-10-02 08:17:40         clear sky -21.6403
# 6             Bosaso      SO  2022-10-02 08:17:41  scattered clouds  11.2842
# 7       Punta Arenas      CL  2022-10-02 08:15:06         clear sky -53.1500
# 8            Kasamwa      TZ  2022-10-02 08:17:41   overcast clouds  -2.8500
# 9       Ebreichsdorf      AT  2022-10-02 08:17:42       shower rain  47.9500
#
#        Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0 -35.7353     67.44        94          20        3.44
# 1  -0.8374     73.98        60           0        8.05
# 2 -24.4956     77.22        72         100        8.97
# 3 -69.3228     68.09        96          47        3.94
# 4  18.4232     75.11        58           0       17.27
# 5 -41.0511     67.66        85           0        8.97
# 6  49.1816     94.71        41          29        6.93
# 7 -70.9167     28.51        86           0        6.91
# 8  32.4333     82.38        36         100        8.52
# 9  16.4000     60.67        77          75       13.80

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reordered_cols = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reordered_cols]

# Display sample data
city_data_df.head()
# Out:
#            City Country                 Date      Lat      Lng  Max Temp  \
# 0        Maceio      BR  2022-10-02 08:16:18  -9.6658 -35.7353     67.44
# 1    San Javier      ES  2022-10-02 08:17:39  37.8063  -0.8374     73.98
# 2    Sao Filipe      CV  2022-10-02 08:17:40  14.8961 -24.4956     77.22
# 3  Barquisimeto      VE  2022-10-02 08:17:40  10.0739 -69.3228     68.09
# 4     Cape Town      ZA  2022-10-02 08:17:08 -33.9258  18.4232     75.11
#
#    Humidity  Cloudiness  Wind Speed       Description
# 0        94          20        3.44        few clouds
# 1        60           0        8.05         clear sky
# 2        72         100        8.97   overcast clouds
# 3        96          47        3.94  scattered clouds
# 4        58           0       17.27         clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Date            object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_path = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_path, index_label='City ID')
