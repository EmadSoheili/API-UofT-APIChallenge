# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import os

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size=2000)
lngs = np.random.uniform(-180, 180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 788

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = f'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}&q='

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_desc,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | batangafo
# Processing Record 2 of Set 1 | clarence town
# Processing Record 3 of Set 1 | verkhoyansk
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | bathsheba
# Processing Record 6 of Set 1 | klaksvik
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | oranjestad
# Processing Record 10 of Set 1 | karatuzskoye
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | nanortalik
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | linhares
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | mahebourg
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | marienburg
# Processing Record 37 of Set 1 | margate
# Processing Record 38 of Set 1 | sampit
# Processing Record 39 of Set 1 | geraldton
# Processing Record 40 of Set 1 | delanggu
# Processing Record 41 of Set 1 | sinnamary
# Processing Record 42 of Set 1 | westport
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | pekan
# Processing Record 46 of Set 1 | vila velha
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | okha
# Processing Record 49 of Set 1 | flinders
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | capaci
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | taoudenni
# Processing Record 5 of Set 2 | aberfoyle
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | sao filipe
# Processing Record 8 of Set 2 | karratha
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | buala
# Processing Record 12 of Set 2 | bowen
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 2 | torbay
# Processing Record 16 of Set 2 | caravelas
# Processing Record 17 of Set 2 | east london
# Processing Record 18 of Set 2 | quatre cocos
# Processing Record 19 of Set 2 | burgeo
# Processing Record 20 of Set 2 | cabanas
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | helmstedt
# Processing Record 23 of Set 2 | makarov
# Processing Record 24 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 2 | aba
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 28 of Set 2 | athabasca
# Processing Record 29 of Set 2 | hobyo
# Processing Record 30 of Set 2 | noumea
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | morehead
# Processing Record 33 of Set 2 | moissac
# Processing Record 34 of Set 2 | ostrovnoy
# Processing Record 35 of Set 2 | berlevag
# Processing Record 36 of Set 2 | abashiri
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | progreso
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | puerto ayora
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | vostok
# Processing Record 44 of Set 2 | vanavara
# Processing Record 45 of Set 2 | ubatuba
# Processing Record 46 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 2 | castro
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | juba
# Processing Record 50 of Set 2 | cabedelo
# Processing Record 1 of Set 3 | qaqortoq
# Processing Record 2 of Set 3 | faya
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | poum
# Processing Record 5 of Set 3 | olafsvik
# Processing Record 6 of Set 3 | sibolga
# Processing Record 7 of Set 3 | kalmunai
# Processing Record 8 of Set 3 | puerto del rosario
# Processing Record 9 of Set 3 | rantepao
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | magadan
# Processing Record 13 of Set 3 | mancio lima
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | novyy urengoy
# Processing Record 19 of Set 3 | alofi
# Processing Record 20 of Set 3 | dong hoi
# Processing Record 21 of Set 3 | labuhan
# Processing Record 22 of Set 3 | paamiut
# Processing Record 23 of Set 3 | beisfjord
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | kardamaina
# Processing Record 26 of Set 3 | kerteh
# City not found. Skipping...
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | ballina
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | yerbogachen
# Processing Record 31 of Set 3 | luderitz
# Processing Record 32 of Set 3 | tilichiki
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | nara
# Processing Record 35 of Set 3 | pisco
# Processing Record 36 of Set 3 | shulan
# Processing Record 37 of Set 3 | sheboygan
# Processing Record 38 of Set 3 | yalvac
# Processing Record 39 of Set 3 | avera
# Processing Record 40 of Set 3 | batsfjord
# Processing Record 41 of Set 3 | rajpura
# Processing Record 42 of Set 3 | doka
# Processing Record 43 of Set 3 | salvador
# Processing Record 44 of Set 3 | datong
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | mahibadhoo
# Processing Record 47 of Set 3 | palu
# Processing Record 48 of Set 3 | butaritari
# Processing Record 49 of Set 3 | aklavik
# Processing Record 50 of Set 3 | vallenar
# Processing Record 1 of Set 4 | yantal
# Processing Record 2 of Set 4 | los llanos de aridane
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | hofn
# Processing Record 5 of Set 4 | biak
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | vinh
# Processing Record 8 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 4 | leningradskiy
# Processing Record 10 of Set 4 | sistranda
# Processing Record 11 of Set 4 | namibe
# Processing Record 12 of Set 4 | thinadhoo
# Processing Record 13 of Set 4 | kanniyakumari
# Processing Record 14 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 4 | kapaa
# Processing Record 16 of Set 4 | road town
# Processing Record 17 of Set 4 | bakchar
# Processing Record 18 of Set 4 | ziro
# Processing Record 19 of Set 4 | san patricio
# Processing Record 20 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | cidreira
# Processing Record 22 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | mandera
# Processing Record 25 of Set 4 | verkhnyaya inta
# Processing Record 26 of Set 4 | tahe
# Processing Record 27 of Set 4 | halol
# Processing Record 28 of Set 4 | sechura
# Processing Record 29 of Set 4 | bereda
# Processing Record 30 of Set 4 | comodoro rivadavia
# Processing Record 31 of Set 4 | arraial do cabo
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | takoradi
# Processing Record 34 of Set 4 | maniitsoq
# Processing Record 35 of Set 4 | chemainus
# Processing Record 36 of Set 4 | po
# City not found. Skipping...
# Processing Record 37 of Set 4 | srednekolymsk
# Processing Record 38 of Set 4 | kudahuvadhoo
# Processing Record 39 of Set 4 | padre bernardo
# Processing Record 40 of Set 4 | kasane
# Processing Record 41 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 42 of Set 4 | russell
# Processing Record 43 of Set 4 | yambio
# Processing Record 44 of Set 4 | acapulco
# Processing Record 45 of Set 4 | milan
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | seoul
# Processing Record 48 of Set 4 | aswan
# Processing Record 49 of Set 4 | airai
# Processing Record 50 of Set 4 | guerrero negro
# Processing Record 1 of Set 5 | nikolskoye
# Processing Record 2 of Set 5 | vitim
# Processing Record 3 of Set 5 | namatanai
# Processing Record 4 of Set 5 | monrovia
# Processing Record 5 of Set 5 | tombouctou
# Processing Record 6 of Set 5 | makakilo city
# Processing Record 7 of Set 5 | bima
# Processing Record 8 of Set 5 | loubomo
# Processing Record 9 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 5 | loudi
# Processing Record 11 of Set 5 | nuevitas
# Processing Record 12 of Set 5 | ngunguru
# Processing Record 13 of Set 5 | vagur
# Processing Record 14 of Set 5 | lavrentiya
# Processing Record 15 of Set 5 | surt
# Processing Record 16 of Set 5 | kuznetsk
# Processing Record 17 of Set 5 | bambous virieux
# Processing Record 18 of Set 5 | trincomalee
# Processing Record 19 of Set 5 | ternate
# Processing Record 20 of Set 5 | aykhal
# Processing Record 21 of Set 5 | urubicha
# Processing Record 22 of Set 5 | aksu
# Processing Record 23 of Set 5 | hobart
# Processing Record 24 of Set 5 | clyde river
# Processing Record 25 of Set 5 | outlook
# Processing Record 26 of Set 5 | poronaysk
# Processing Record 27 of Set 5 | ahuimanu
# Processing Record 28 of Set 5 | la ronge
# Processing Record 29 of Set 5 | raudeberg
# Processing Record 30 of Set 5 | vanimo
# Processing Record 31 of Set 5 | buturlino
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | rio bueno
# Processing Record 34 of Set 5 | hithadhoo
# Processing Record 35 of Set 5 | union
# Processing Record 36 of Set 5 | broome
# Processing Record 37 of Set 5 | portland
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | atkinson
# Processing Record 40 of Set 5 | shenjiamen
# Processing Record 41 of Set 5 | bodden town
# Processing Record 42 of Set 5 | port-cartier
# Processing Record 43 of Set 5 | inuvik
# Processing Record 44 of Set 5 | lukovetskiy
# Processing Record 45 of Set 5 | kabarnet
# Processing Record 46 of Set 5 | yumen
# Processing Record 47 of Set 5 | rosarito
# Processing Record 48 of Set 5 | isangel
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 50 of Set 5 | kamenka
# Processing Record 1 of Set 6 | kasangulu
# Processing Record 2 of Set 6 | bengkulu
# Processing Record 3 of Set 6 | hokitika
# Processing Record 4 of Set 6 | devarkonda
# Processing Record 5 of Set 6 | ures
# Processing Record 6 of Set 6 | teya
# Processing Record 7 of Set 6 | talnakh
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | dossor
# Processing Record 10 of Set 6 | ambon
# Processing Record 11 of Set 6 | homer
# Processing Record 12 of Set 6 | bethel
# Processing Record 13 of Set 6 | correntina
# Processing Record 14 of Set 6 | upernavik
# Processing Record 15 of Set 6 | hamilton
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | teyateyaneng
# Processing Record 18 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | chavinda
# Processing Record 20 of Set 6 | alghero
# Processing Record 21 of Set 6 | sao joao da barra
# Processing Record 22 of Set 6 | dongsheng
# Processing Record 23 of Set 6 | constitucion
# Processing Record 24 of Set 6 | riviere-au-renard
# Processing Record 25 of Set 6 | bargur
# Processing Record 26 of Set 6 | borama
# City not found. Skipping...
# Processing Record 27 of Set 6 | klyuchi
# Processing Record 28 of Set 6 | henties bay
# Processing Record 29 of Set 6 | pangoa
# Processing Record 30 of Set 6 | kapit
# Processing Record 31 of Set 6 | belmonte
# Processing Record 32 of Set 6 | santa maria
# Processing Record 33 of Set 6 | sur
# Processing Record 34 of Set 6 | ayagoz
# Processing Record 35 of Set 6 | havoysund
# Processing Record 36 of Set 6 | kloulklubed
# Processing Record 37 of Set 6 | maneadero
# Processing Record 38 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 6 | hurghada
# Processing Record 40 of Set 6 | shalakusha
# Processing Record 41 of Set 6 | kahului
# Processing Record 42 of Set 6 | cabo san lucas
# Processing Record 43 of Set 6 | ixtapa
# Processing Record 44 of Set 6 | general roca
# Processing Record 45 of Set 6 | mayumba
# Processing Record 46 of Set 6 | ilulissat
# Processing Record 47 of Set 6 | patos de minas
# Processing Record 48 of Set 6 | miloslavskoye
# Processing Record 49 of Set 6 | umm lajj
# Processing Record 50 of Set 6 | campbell river
# Processing Record 1 of Set 7 | kosh-agach
# Processing Record 2 of Set 7 | san quintin
# Processing Record 3 of Set 7 | pandan
# Processing Record 4 of Set 7 | hvide sande
# Processing Record 5 of Set 7 | vardo
# Processing Record 6 of Set 7 | avarua
# Processing Record 7 of Set 7 | lompoc
# Processing Record 8 of Set 7 | santa vitoria do palmar
# Processing Record 9 of Set 7 | mugur-aksy
# Processing Record 10 of Set 7 | cheney
# Processing Record 11 of Set 7 | goundam
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | gravelbourg
# Processing Record 14 of Set 7 | kharp
# Processing Record 15 of Set 7 | guiratinga
# Processing Record 16 of Set 7 | bawku
# Processing Record 17 of Set 7 | cascais
# Processing Record 18 of Set 7 | wiwili
# Processing Record 19 of Set 7 | mabaruma
# Processing Record 20 of Set 7 | kavieng
# Processing Record 21 of Set 7 | newport
# Processing Record 22 of Set 7 | tuy hoa
# Processing Record 23 of Set 7 | abomsa
# Processing Record 24 of Set 7 | sioux lookout
# Processing Record 25 of Set 7 | roma
# Processing Record 26 of Set 7 | araouane
# Processing Record 27 of Set 7 | lewisporte
# Processing Record 28 of Set 7 | palembang
# Processing Record 29 of Set 7 | wajid
# Processing Record 30 of Set 7 | tarabha
# Processing Record 31 of Set 7 | astoria
# Processing Record 32 of Set 7 | pedernales
# Processing Record 33 of Set 7 | lata
# Processing Record 34 of Set 7 | grand gaube
# Processing Record 35 of Set 7 | pacific grove
# Processing Record 36 of Set 7 | penzance
# Processing Record 37 of Set 7 | itarema
# Processing Record 38 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 39 of Set 7 | marinette
# Processing Record 40 of Set 7 | zyryanka
# Processing Record 41 of Set 7 | coquimbo
# Processing Record 42 of Set 7 | trujillo
# Processing Record 43 of Set 7 | soller
# Processing Record 44 of Set 7 | leshukonskoye
# Processing Record 45 of Set 7 | nantucket
# Processing Record 46 of Set 7 | port blair
# Processing Record 47 of Set 7 | manuk mangkaw
# Processing Record 48 of Set 7 | kalaleh
# Processing Record 49 of Set 7 | nancha
# Processing Record 50 of Set 7 | tlahualilo
# City not found. Skipping...
# Processing Record 1 of Set 8 | banjar
# Processing Record 2 of Set 8 | mola di bari
# Processing Record 3 of Set 8 | burica
# City not found. Skipping...
# Processing Record 4 of Set 8 | san policarpo
# Processing Record 5 of Set 8 | longyearbyen
# Processing Record 6 of Set 8 | kutno
# Processing Record 7 of Set 8 | aguililla
# Processing Record 8 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 8 | dwarka
# Processing Record 10 of Set 8 | ahipara
# Processing Record 11 of Set 8 | atar
# Processing Record 12 of Set 8 | nemuro
# Processing Record 13 of Set 8 | gushikawa
# Processing Record 14 of Set 8 | deputatskiy
# Processing Record 15 of Set 8 | wajima
# Processing Record 16 of Set 8 | shimonoseki
# Processing Record 17 of Set 8 | plouzane
# Processing Record 18 of Set 8 | richards bay
# Processing Record 19 of Set 8 | saint george
# Processing Record 20 of Set 8 | shahrud
# Processing Record 21 of Set 8 | goderich
# Processing Record 22 of Set 8 | bazpur
# Processing Record 23 of Set 8 | roald
# Processing Record 24 of Set 8 | touros
# Processing Record 25 of Set 8 | zabol
# Processing Record 26 of Set 8 | mayo
# Processing Record 27 of Set 8 | ust-nera
# Processing Record 28 of Set 8 | cockburn town
# Processing Record 29 of Set 8 | flin flon
# Processing Record 30 of Set 8 | sandnessjoen
# Processing Record 31 of Set 8 | nahrin
# Processing Record 32 of Set 8 | dakar
# Processing Record 33 of Set 8 | roebourne
# Processing Record 34 of Set 8 | kjollefjord
# Processing Record 35 of Set 8 | dunedin
# Processing Record 36 of Set 8 | grand forks
# Processing Record 37 of Set 8 | sursk
# Processing Record 38 of Set 8 | xuddur
# Processing Record 39 of Set 8 | beloha
# Processing Record 40 of Set 8 | denpasar
# Processing Record 41 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 8 | ossora
# Processing Record 43 of Set 8 | algeciras
# Processing Record 44 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 8 | yandyki
# Processing Record 46 of Set 8 | soyo
# Processing Record 47 of Set 8 | barra dos coqueiros
# Processing Record 48 of Set 8 | minot
# Processing Record 49 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 50 of Set 8 | chake chake
# Processing Record 1 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 2 of Set 9 | hasaki
# Processing Record 3 of Set 9 | jerantut
# Processing Record 4 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | fairbanks
# Processing Record 6 of Set 9 | severo-kurilsk
# Processing Record 7 of Set 9 | souillac
# Processing Record 8 of Set 9 | cruzeiro
# Processing Record 9 of Set 9 | betong
# Processing Record 10 of Set 9 | yinchuan
# Processing Record 11 of Set 9 | palmares do sul
# Processing Record 12 of Set 9 | beringovskiy
# Processing Record 13 of Set 9 | mongo
# Processing Record 14 of Set 9 | madingou
# Processing Record 15 of Set 9 | zhezkazgan
# Processing Record 16 of Set 9 | gaogou
# Processing Record 17 of Set 9 | shache
# Processing Record 18 of Set 9 | samfya
# Processing Record 19 of Set 9 | humberto de campos
# Processing Record 20 of Set 9 | alice springs
# Processing Record 21 of Set 9 | tomatlan
# Processing Record 22 of Set 9 | el alto
# Processing Record 23 of Set 9 | ati
# Processing Record 24 of Set 9 | nur
# Processing Record 25 of Set 9 | port hedland
# Processing Record 26 of Set 9 | tecoanapa
# Processing Record 27 of Set 9 | boundiali
# Processing Record 28 of Set 9 | khani
# Processing Record 29 of Set 9 | yzeure
# Processing Record 30 of Set 9 | helong
# Processing Record 31 of Set 9 | haines junction
# Processing Record 32 of Set 9 | jurm
# Processing Record 33 of Set 9 | tura
# Processing Record 34 of Set 9 | qandala
# Processing Record 35 of Set 9 | belawan
# Processing Record 36 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 9 | tatarsk
# Processing Record 38 of Set 9 | le pradet
# Processing Record 39 of Set 9 | omboue
# Processing Record 40 of Set 9 | tuatapere
# Processing Record 41 of Set 9 | zaragoza
# Processing Record 42 of Set 9 | manggar
# Processing Record 43 of Set 9 | shar
# Processing Record 44 of Set 9 | mosquera
# Processing Record 45 of Set 9 | vrangel
# Processing Record 46 of Set 9 | wilmington
# Processing Record 47 of Set 9 | mehamn
# Processing Record 48 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 9 | darab
# Processing Record 50 of Set 9 | skjervoy
# Processing Record 1 of Set 10 | grenfell
# Processing Record 2 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 10 | pingliang
# Processing Record 5 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 10 | bud
# Processing Record 7 of Set 10 | cayenne
# Processing Record 8 of Set 10 | coihaique
# Processing Record 9 of Set 10 | viedma
# Processing Record 10 of Set 10 | mayor pablo lagerenza
# Processing Record 11 of Set 10 | kiama
# Processing Record 12 of Set 10 | griffith
# Processing Record 13 of Set 10 | waipawa
# Processing Record 14 of Set 10 | san pedro de macoris
# Processing Record 15 of Set 10 | shumskiy
# Processing Record 16 of Set 10 | darhan
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | camacha
# Processing Record 19 of Set 10 | miracema do tocantins
# Processing Record 20 of Set 10 | haapiti
# Processing Record 21 of Set 10 | rundu
# Processing Record 22 of Set 10 | norman wells
# Processing Record 23 of Set 10 | kiunga
# Processing Record 24 of Set 10 | waitara
# Processing Record 25 of Set 10 | khombole
# Processing Record 26 of Set 10 | saint-leu
# Processing Record 27 of Set 10 | sakakah
# Processing Record 28 of Set 10 | torquay
# Processing Record 29 of Set 10 | quelimane
# Processing Record 30 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 31 of Set 10 | bay roberts
# Processing Record 32 of Set 10 | ca mau
# Processing Record 33 of Set 10 | changji
# Processing Record 34 of Set 10 | nador
# Processing Record 35 of Set 10 | burnie
# Processing Record 36 of Set 10 | lugovskiy
# City not found. Skipping...
# Processing Record 37 of Set 10 | saraza
# Processing Record 38 of Set 10 | jalu
# Processing Record 39 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 10 | port hardy
# Processing Record 41 of Set 10 | djougou
# Processing Record 42 of Set 10 | arlit
# Processing Record 43 of Set 10 | achutupo
# Processing Record 44 of Set 10 | lichuan
# Processing Record 45 of Set 10 | kimbe
# Processing Record 46 of Set 10 | naze
# Processing Record 47 of Set 10 | sept-iles
# Processing Record 48 of Set 10 | schramberg
# Processing Record 49 of Set 10 | kathu
# Processing Record 50 of Set 10 | kyrylivka
# Processing Record 1 of Set 11 | tchollire
# Processing Record 2 of Set 11 | wicklow
# Processing Record 3 of Set 11 | pitsunda
# Processing Record 4 of Set 11 | mincivan
# Processing Record 5 of Set 11 | jaffna
# Processing Record 6 of Set 11 | lushunkou
# City not found. Skipping...
# Processing Record 7 of Set 11 | grindavik
# Processing Record 8 of Set 11 | zaysan
# Processing Record 9 of Set 11 | koungou
# Processing Record 10 of Set 11 | biskamzha
# Processing Record 11 of Set 11 | potrero del llano
# Processing Record 12 of Set 11 | asau
# Processing Record 13 of Set 11 | hami
# Processing Record 14 of Set 11 | mount gambier
# Processing Record 15 of Set 11 | talaja
# Processing Record 16 of Set 11 | keetmanshoop
# Processing Record 17 of Set 11 | nizhniy kuranakh
# Processing Record 18 of Set 11 | yenagoa
# Processing Record 19 of Set 11 | chernyshevskiy
# Processing Record 20 of Set 11 | mookane
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | manaus
# Processing Record 23 of Set 11 | san cristobal
# Processing Record 24 of Set 11 | kuloy
# Processing Record 25 of Set 11 | zhanaozen
# Processing Record 26 of Set 11 | mbengwi
# Processing Record 27 of Set 11 | amapa
# Processing Record 28 of Set 11 | kangaatsiaq
# Processing Record 29 of Set 11 | jacobabad
# Processing Record 30 of Set 11 | stavern
# Processing Record 31 of Set 11 | itaueira
# Processing Record 32 of Set 11 | ust-kuyga
# Processing Record 33 of Set 11 | helena
# Processing Record 34 of Set 11 | nikolayevsk-na-amure
# Processing Record 35 of Set 11 | waseca
# Processing Record 36 of Set 11 | elko
# Processing Record 37 of Set 11 | nicoya
# Processing Record 38 of Set 11 | putina
# Processing Record 39 of Set 11 | arkhangelsk
# Processing Record 40 of Set 11 | mooresville
# Processing Record 41 of Set 11 | sal rei
# Processing Record 42 of Set 11 | sembakung
# Processing Record 43 of Set 11 | abu dhabi
# Processing Record 44 of Set 11 | balabac
# Processing Record 45 of Set 11 | havre-saint-pierre
# Processing Record 46 of Set 11 | paita
# Processing Record 47 of Set 11 | pouebo
# Processing Record 48 of Set 11 | machico
# Processing Record 49 of Set 11 | abu zabad
# Processing Record 50 of Set 11 | saint-augustin
# Processing Record 1 of Set 12 | mogadishu
# Processing Record 2 of Set 12 | bang saphan
# Processing Record 3 of Set 12 | hovd
# Processing Record 4 of Set 12 | zhigansk
# Processing Record 5 of Set 12 | katobu
# Processing Record 6 of Set 12 | kozhva
# Processing Record 7 of Set 12 | merauke
# Processing Record 8 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 12 | thohoyandou
# Processing Record 10 of Set 12 | kumluca
# Processing Record 11 of Set 12 | lewiston
# Processing Record 12 of Set 12 | karangasem
# Processing Record 13 of Set 12 | ugoofaaru
# Processing Record 14 of Set 12 | petawawa
# Processing Record 15 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 16 of Set 12 | mhango
# Processing Record 17 of Set 12 | samarai
# Processing Record 18 of Set 12 | teguise
# Processing Record 19 of Set 12 | caconda
# Processing Record 20 of Set 12 | san vicente
# Processing Record 21 of Set 12 | sokoni
# Processing Record 22 of Set 12 | luganville
# Processing Record 23 of Set 12 | tofield
# Processing Record 24 of Set 12 | kirakira
# Processing Record 25 of Set 12 | kutum
# Processing Record 26 of Set 12 | auly
# Processing Record 27 of Set 12 | san jeronimo
# Processing Record 28 of Set 12 | huescar
# Processing Record 29 of Set 12 | tiruvottiyur
# City not found. Skipping...
# Processing Record 30 of Set 12 | pangnirtung
# Processing Record 31 of Set 12 | beibei
# Processing Record 32 of Set 12 | iqaluit
# Processing Record 33 of Set 12 | antalaha
# Processing Record 34 of Set 12 | varnamo
# Processing Record 35 of Set 12 | padang
# Processing Record 36 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 12 | lima
# Processing Record 38 of Set 12 | leh
# Processing Record 39 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 12 | evensk
# Processing Record 41 of Set 12 | ketchikan
# Processing Record 42 of Set 12 | galesong
# Processing Record 43 of Set 12 | nome
# Processing Record 44 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 45 of Set 12 | bubaque
# Processing Record 46 of Set 12 | aranos
# Processing Record 47 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 12 | gondar
# Processing Record 49 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 50 of Set 12 | menongue
# Processing Record 1 of Set 13 | acajutla
# Processing Record 2 of Set 13 | dolores
# Processing Record 3 of Set 13 | susanville
# Processing Record 4 of Set 13 | panjab
# Processing Record 5 of Set 13 | sambava
# Processing Record 6 of Set 13 | balkanabat
# Processing Record 7 of Set 13 | komsomolskiy
# Processing Record 8 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 9 of Set 13 | charters towers
# Processing Record 10 of Set 13 | suibara
# Processing Record 11 of Set 13 | laguna
# Processing Record 12 of Set 13 | kontagora
# Processing Record 13 of Set 13 | karonga
# Processing Record 14 of Set 13 | akyab
# Processing Record 15 of Set 13 | makubetsu
# Processing Record 16 of Set 13 | shevchenkove
# Processing Record 17 of Set 13 | san-pedro
# Processing Record 18 of Set 13 | krasnoselkup
# Processing Record 19 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 13 | vigrestad
# Processing Record 21 of Set 13 | santa fe
# Processing Record 22 of Set 13 | chara
# Processing Record 23 of Set 13 | mbandaka
# Processing Record 24 of Set 13 | natal
# Processing Record 25 of Set 13 | jackson
# Processing Record 26 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 13 | almeirim
# Processing Record 28 of Set 13 | zamora
# Processing Record 29 of Set 13 | muhos
# Processing Record 30 of Set 13 | san rafael
# Processing Record 31 of Set 13 | hambantota
# Processing Record 32 of Set 13 | prieska
# Processing Record 33 of Set 13 | sibu
# Processing Record 34 of Set 13 | bontang
# Processing Record 35 of Set 13 | bagdarin
# Processing Record 36 of Set 13 | itacoatiara
# Processing Record 37 of Set 13 | sola
# Processing Record 38 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 13 | tiznit
# Processing Record 40 of Set 13 | poso
# Processing Record 41 of Set 13 | usinsk
# Processing Record 42 of Set 13 | nisia floresta
# Processing Record 43 of Set 13 | bishop auckland
# Processing Record 44 of Set 13 | kalangala
# Processing Record 45 of Set 13 | sabang
# Processing Record 46 of Set 13 | meulaboh
# Processing Record 47 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 13 | batemans bay
# Processing Record 49 of Set 13 | curico
# Processing Record 50 of Set 13 | cherskiy
# Processing Record 1 of Set 14 | contamana
# Processing Record 2 of Set 14 | gazanjyk
# Processing Record 3 of Set 14 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 14 | humaita
# Processing Record 5 of Set 14 | hisar
# Processing Record 6 of Set 14 | turzovka
# Processing Record 7 of Set 14 | rocha
# Processing Record 8 of Set 14 | pizarro
# Processing Record 9 of Set 14 | likasi
# Processing Record 10 of Set 14 | bandarbeyla
# Processing Record 11 of Set 14 | sobradinho
# Processing Record 12 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 14 | rassvet
# Processing Record 14 of Set 14 | turmalina
# Processing Record 15 of Set 14 | lagoa vermelha
# Processing Record 16 of Set 14 | tahta
# Processing Record 17 of Set 14 | minchinabad
# Processing Record 18 of Set 14 | nyaunglebin
# Processing Record 19 of Set 14 | tigzirt
# Processing Record 20 of Set 14 | pitimbu
# Processing Record 21 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 22 of Set 14 | independencia
# Processing Record 23 of Set 14 | tabou
# Processing Record 24 of Set 14 | port washington
# Processing Record 25 of Set 14 | alenquer
# Processing Record 26 of Set 14 | cortez
# Processing Record 27 of Set 14 | buin
# Processing Record 28 of Set 14 | hirara
# Processing Record 29 of Set 14 | kassala
# Processing Record 30 of Set 14 | obihiro
# Processing Record 31 of Set 14 | baykit
# Processing Record 32 of Set 14 | saint-francois
# Processing Record 33 of Set 14 | tondano
# Processing Record 34 of Set 14 | cowra
# Processing Record 35 of Set 14 | baft
# Processing Record 36 of Set 14 | jiroft
# City not found. Skipping...
# Processing Record 37 of Set 14 | yatou
# Processing Record 38 of Set 14 | saskatoon
# Processing Record 39 of Set 14 | port hueneme
# Processing Record 40 of Set 14 | nizwa
# Processing Record 41 of Set 14 | scarborough
# Processing Record 42 of Set 14 | borogontsy
# Processing Record 43 of Set 14 | placido de castro
# Processing Record 44 of Set 14 | egvekinot
# Processing Record 45 of Set 14 | salto de agua
# Processing Record 46 of Set 14 | kedzierzyn-kozle
# Processing Record 47 of Set 14 | den helder
# Processing Record 48 of Set 14 | bonavista
# Processing Record 49 of Set 14 | kidal
# Processing Record 50 of Set 14 | fort nelson
# Processing Record 1 of Set 15 | port jervis
# Processing Record 2 of Set 15 | balti
# Processing Record 3 of Set 15 | mecca
# Processing Record 4 of Set 15 | mezen
# Processing Record 5 of Set 15 | dig
# Processing Record 6 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 7 of Set 15 | mangochi
# Processing Record 8 of Set 15 | gudur
# Processing Record 9 of Set 15 | umm kaddadah
# Processing Record 10 of Set 15 | herzberg
# Processing Record 11 of Set 15 | maputo
# Processing Record 12 of Set 15 | plettenberg bay
# Processing Record 13 of Set 15 | mangan
# Processing Record 14 of Set 15 | leshan
# Processing Record 15 of Set 15 | orcopampa
# Processing Record 16 of Set 15 | broken hill
# Processing Record 17 of Set 15 | doliana
# Processing Record 18 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 15 | sainte-rose
# Processing Record 20 of Set 15 | garowe
# Processing Record 21 of Set 15 | bandar-e lengeh
# Processing Record 22 of Set 15 | suzun
# Processing Record 23 of Set 15 | tsabong
# Processing Record 24 of Set 15 | renigunta
# Processing Record 25 of Set 15 | pinega
# Processing Record 26 of Set 15 | bantou
# Processing Record 27 of Set 15 | manaure
# Processing Record 28 of Set 15 | sorland
# Processing Record 29 of Set 15 | barguzin
# Processing Record 30 of Set 15 | khandyga
# Processing Record 31 of Set 15 | brigantine
# Processing Record 32 of Set 15 | hagi
# Processing Record 33 of Set 15 | kardla
# Processing Record 34 of Set 15 | yacuiba
# Processing Record 35 of Set 15 | college
# Processing Record 36 of Set 15 | sobolevo
# Processing Record 37 of Set 15 | rosetta
# Processing Record 38 of Set 15 | raymondville
# Processing Record 39 of Set 15 | uvira
# Processing Record 40 of Set 15 | zabolotovka
# Processing Record 41 of Set 15 | mao
# Processing Record 42 of Set 15 | dudinka
# Processing Record 43 of Set 15 | payo
# Processing Record 44 of Set 15 | peleduy
# Processing Record 45 of Set 15 | rongcheng
# Processing Record 46 of Set 15 | vero beach
# Processing Record 47 of Set 15 | tartagal
# Processing Record 48 of Set 15 | ucluelet
# Processing Record 49 of Set 15 | mitu
# Processing Record 50 of Set 15 | iwanai
# Processing Record 1 of Set 16 | panzhihua
# Processing Record 2 of Set 16 | rawson
# Processing Record 3 of Set 16 | katiola
# Processing Record 4 of Set 16 | edgewater
# Processing Record 5 of Set 16 | jieshi
# Processing Record 6 of Set 16 | saint-junien
# Processing Record 7 of Set 16 | kieta
# Processing Record 8 of Set 16 | harper
# Processing Record 9 of Set 16 | kaeo
# Processing Record 10 of Set 16 | kallithea
# Processing Record 11 of Set 16 | siocon
# Processing Record 12 of Set 16 | jumla
# Processing Record 13 of Set 16 | port-gentil
# Processing Record 14 of Set 16 | vao
# Processing Record 15 of Set 16 | ciras
# City not found. Skipping...
# Processing Record 16 of Set 16 | muros
# Processing Record 17 of Set 16 | puri
# Processing Record 18 of Set 16 | saint-pierre
# Processing Record 19 of Set 16 | tual
# Processing Record 20 of Set 16 | springbok
# Processing Record 21 of Set 16 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 22 of Set 16 | reinbek
# Processing Record 23 of Set 16 | salym
# Processing Record 24 of Set 16 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 16 | murgab
# Processing Record 26 of Set 16 | monaragala
# Processing Record 27 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 16 | ponca city
# Processing Record 29 of Set 16 | port hawkesbury
# Processing Record 30 of Set 16 | jiuquan
# Processing Record 31 of Set 16 | shubarkuduk
# Processing Record 32 of Set 16 | muisne
# Processing Record 33 of Set 16 | rabo de peixe
# Processing Record 34 of Set 16 | nyurba
# Processing Record 35 of Set 16 | tabarqah
# City not found. Skipping...
# Processing Record 36 of Set 16 | wuwei
# Processing Record 37 of Set 16 | wawa
# Processing Record 38 of Set 16 | sindor
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 723

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City Country                 Date Current Description      Lat  \
# 0      Batangafo      CF  2022-10-02 16:01:59     overcast clouds   7.3008
# 1  Clarence Town      AU  2022-10-02 16:01:59           clear sky -32.5833
# 2    Verkhoyansk      RU  2022-10-02 16:02:00     overcast clouds  67.5447
# 3           Lebu      CL  2022-10-02 16:02:00     overcast clouds -37.6167
# 4      Bathsheba      BB  2022-10-02 15:57:41    scattered clouds  13.2167
# 5       Klaksvik      FO  2022-10-02 16:02:01           clear sky  62.2266
# 6        Ushuaia      AR  2022-10-02 15:57:48           clear sky -54.8000
# 7       Victoria      HK  2022-10-02 15:54:28          few clouds  22.2855
# 8     Oranjestad      AW  2022-10-02 16:02:01       broken clouds  12.5240
# 9   Karatuzskoye      RU  2022-10-02 16:02:02          few clouds  53.6072
#
#         Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0   18.2833     80.37        79          93        1.66
# 1  151.7833     54.86        94           0        2.46
# 2  133.3850     19.26        96         100        2.84
# 3  -73.6500     59.02        69         100        6.06
# 4  -59.5167     88.41        70          40       19.57
# 5   -6.5890     52.72        81          10       26.60
# 6  -68.3000     44.26        53           0        4.61
# 7  114.1577     84.38        83          18        8.01
# 8  -70.0270     84.18        78          52       16.44
# 9   92.8667     28.54        68          13        2.73

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Date', 'Current Description', 'Lat', 'Lng',
#        'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
reordered_cols = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[reordered_cols]

# Display sample data
city_data_df.head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0      Batangafo      CF  2022-10-02 16:01:59   7.3008   18.2833     80.37
# 1  Clarence Town      AU  2022-10-02 16:01:59 -32.5833  151.7833     54.86
# 2    Verkhoyansk      RU  2022-10-02 16:02:00  67.5447  133.3850     19.26
# 3           Lebu      CL  2022-10-02 16:02:00 -37.6167  -73.6500     59.02
# 4      Bathsheba      BB  2022-10-02 15:57:41  13.2167  -59.5167     88.41
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        79          93        1.66     overcast clouds
# 1        94           0        2.46           clear sky
# 2        96         100        2.84     overcast clouds
# 3        69         100        6.06     overcast clouds
# 4        70          40       19.57    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_path = os.path.join('WeatherPy_Database.csv')

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_path, index_label='City ID')
